# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhant012/Open-AI-Gym-colab/blob/main/gym_test_breakout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyvirtualdisplay
# !apt install xvfb -y
import gym
from pyvirtualdisplay import Display
from IPython.display import display
from IPython.display import clear_output
import PIL
import time
import numpy as np
import random
import math
import sys
import re
from tensorflow import keras
from cv2 import resize as cv2_resize
#Display(visible=0, size=(1400,900)).start()
# Out:
# Collecting pyvirtualdisplay
#   Downloading https://files.pythonhosted.org/packages/d0/8a/643043cc70791367bee2d19eb20e00ed1a246ac48e5dbe57bbbcc8be40a9/PyVirtualDisplay-1.3.2-py2.py3-none-any.whl
# Collecting EasyProcess
#   Downloading https://files.pythonhosted.org/packages/48/3c/75573613641c90c6d094059ac28adb748560d99bd27ee6f80cce398f404e/EasyProcess-0.3-py2.py3-none-any.whl
# Installing collected packages: EasyProcess, pyvirtualdisplay
# Successfully installed EasyProcess-0.3 pyvirtualdisplay-1.3.2
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   xvfb
# 0 upgraded, 1 newly installed, 0 to remove and 21 not upgraded.
# Need to get 783 kB of archives.
# After this operation, 2,266 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.7 [783 kB]
# Fetched 783 kB in 2s (363 kB/s)
# Selecting previously unselected package xvfb.
# (Reading database ... 144611 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.7_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.7) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.7) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
class PolicyNet:

    def __init__(self,load_name="",save_name=""):

        self.load_name=load_name
        self.save_name=save_name
        self.learning_rate=0.01
        self.loss="mse"
        self.policy=None
    
    def build_model(self,input_shape,output_shape,learning_rate=0.01,loss="mse"):
        self.learning_rate=learning_rate
        self.loss=loss

        if(len(self.load_name)>0):
            self.model=keras.models.load_model(self.load_name)
        else:
            '''self.model=keras.Sequential()
            self.model.add(keras.layers.Dense(50,input_shape=input_shape,activation="relu"))
            self.model.add(keras.layers.Dense(50,activation="relu"))
            self.model.add(keras.layers.Dense(units=output_shape,activation="linear"))'''

            self.model=keras.Sequential()
            self.model.add(keras.layers.Conv2D(32, kernel_size=(3,3), input_shape=input_shape,activation="relu",padding="valid"))
            self.model.add(keras.layers.MaxPool2D(pool_size=(2,2)))
            #self.model.add(keras.layers.Conv2D(32, kernel_size=(3,3),activation="relu",padding="valid"))
            #self.model.add(keras.layers.MaxPool2D(pool_size=(2,2)))
            self.model.add(keras.layers.Flatten())
            self.model.add(keras.layers.Dense(128,activation="relu"))
            self.model.add(keras.layers.Dense(64,activation="relu"))
            self.model.add(keras.layers.Dense(units=output_shape,activation="linear"))

            self.model.compile(optimizer=keras.optimizers.Adam(lr=self.learning_rate),loss=self.loss)

        return self.model

    def preprocess_inputs(self,inputs):
        inputs=np.expand_dims(inputs.astype(np.float32).mean(axis=3),axis=3)/255.0
        inputs=inputs[:,60:-10,10:-10,:]
        inputs=np.expand_dims( np.array([cv2_resize(inputs[i],(70,70)) for i in range(len(inputs))]).astype(np.float32),axis=3 )
        return inputs

    def get_model(self):
        return self.model
    
    def get_model_weights(self):
        return self.model.get_weights()

    def get_hyperparameters(self):
        return dict([('learning_rate',self.learning_rate),('loss',self.loss)])

    def save_model(self):
        if(len(self.save_name)>0) : self.model.save(self.save_name)
    
    def train_model(self,inputs,outputs):
        inputs=self.preprocess_inputs(inputs)
        self.model.fit(inputs.astype(np.float32),outputs.astype(np.float32),epochs=1,batch_size=1,verbose=0,shuffle=False)
    
    def get_Qvals(self,inputs):
        inputs=self.preprocess_inputs(inputs)
        Qvals=self.model.predict(inputs.astype(np.float32))
        return Qvals
    
    def get_policy_from_Qvals(self,Qvals):
        self.policy=np.exp(Qvals) / np.sum(np.exp(Qvals), axis=0)
        return self.policy

class TargetNet:

    def __init__(self,policy_net,target_update=10):
        self.policy_net=policy_net
        self.target_update=target_update
    
    def build_model(self):
        self.model=keras.models.clone_model(self.policy_net.model)
        hyperparameters=self.policy_net.get_hyperparameters()
        learning_rate=hyperparameters['learning_rate']
        loss=hyperparameters['loss']

        self.model.compile(optimizer=keras.optimizers.Adam(lr=learning_rate),loss=loss)
        return self.model

    def set_model_weights(self):
        self.model.set_weights(self.policy_net.get_model_weights())

    def get_target_Qvals(self,inputs,step):
        if(step%self.target_update==0) : self.set_model_weights()
        inputs=self.policy_net.preprocess_inputs(inputs)
        return self.model.predict(inputs.astype(np.float32))


class ReplayMemory:
    def __init__(self,capacity,batch_size):
        self.capacity=capacity
        self.batch_size=batch_size
        self.memory=[]
        self.push_count=0

    def push(self,experience):
        if(len(self.memory)<self.capacity):
            self.memory.append(experience)
        else:
            self.memory[self.push_count%self.capacity]=experience
        self.push_count+=1
    
    def sample(self):
        return random.sample(self.memory,self.batch_size)
    
    def can_provide_sample(self):
        return len(self.memory)>=self.batch_size



class ExploreExploitStrat:
    def __init__(self,strategy):
        self.strategy=strategy

    def get_exploration_rate(self,current_step):
        return self.strategy.get_exploration_rate(current_step)

class EpsilonGreedyStrategy:
    def __init__(self,start,end,decay_rate):
        self.start=start
        self.end=end
        self.decay_rate=decay_rate

    def get_exploration_rate(self,current_step):
        return self.end + (self.start-self.end)*math.exp(-1*current_step*self.decay_rate)


class ReturnStrat:
    def __init__(self,strategy):
        self.strategy=strategy

    def get_return(self,rewards,next_Qvals,dones,current_step):
        return self.strategy.get_return(rewards,next_Qvals,dones,current_step)

class DiscountedReturn:
    def __init__(self,Y=0.5):
        self.Y=Y

    def get_return(self,rewards,next_Qvals,dones,current_step):
        return rewards+(1-dones)*self.Y*next_Qvals


class EnvManager:
    
    def __init__(self,env_name):
        self.env_name=env_name

        self.observation=None
        self.done=None
        self.env_obj=None
        self.display_obj=None
        
    def reset(self):
        self.observation=self.env_obj.reset()
        self.done=False
    
    def load(self):
        self.display_obj=Display(visible=0, size=(14,9))
        self.display_obj.start()
        self.env_obj=gym.make(self.env_name)
        return self.env_obj
        
    def close(self):
        #self.display_obj.stop()
        self.env_obj.close()

    def render(self):
        frame=PIL.Image.fromarray(self.env_obj.render(mode='rgb_array'))
        clear_output(wait=True)
        display(frame)
        #time.sleep(0.1)

    def get_actions_num(self):
        return self.env_obj.action_space.n-1
    
    def get_observation_shape(self):
        return np.array(self.env_obj.state).shape

    def get_current_observation(self):
        return self.observation
    
    def change(self,action):
        action+=1
        if(self.done) : self.reset()

        self.observation,reward,self.done,info=self.env_obj.step(action)

        self.reward=self.modify_reward(reward,self.observation,self.done)
        self.observation=self.modify_observation(self.observation)

        return self.observation,self.reward,self.done

    def modify_observation(self,observation):
        return observation
    
    def modify_reward(self,reward,observation,done):
        if(done) : reward=-10
        #reward = observation[0] + 0.5
        #if(observation[0]>=0.5) : reward+=10
        return reward



class Agent:

    def __init__(self,env_manager,replay_mem,explore_exploit_strat,return_strat,policy_net,target_net):
        self.env_manager=env_manager
        self.replay_mem=replay_mem
        self.explore_exploit_strat=explore_exploit_strat
        self.return_strat=return_strat
        self.policy_net=policy_net
        self.target_net=target_net

        self.action_approach="deterministic"

    def choose_action(self,policy):
        if(self.action_approach=="deterministic"):
            action=np.argmax(policy,axis=0)
        elif(self.action_approach=="stochastic"):
            action=np.random.choice(self.env_manager.get_actions_num(),p=policy)
        return action


    def take_action(self,current_step):

        observation=self.env_manager.get_current_observation()
        exploration_rate=self.explore_exploit_strat.get_exploration_rate(current_step)
        if(random.random()<exploration_rate) :  
            action=random.randrange(self.env_manager.get_actions_num())

        else : 
            curr_Qvals=self.policy_net.get_Qvals(np.expand_dims(observation,axis=0))
            curr_policy=self.policy_net.get_policy_from_Qvals(np.squeeze(curr_Qvals))
            action=self.choose_action(curr_policy)

        next_observation,reward,done=self.env_manager.change(action)
        experience=(observation,action,next_observation,reward,done)

        return experience

    def learn(self,experience,current_step):
        self.replay_mem.push(experience)

        if(self.replay_mem.can_provide_sample()):
            samples=self.replay_mem.sample()
            observations,actions,next_observations,rewards,dones = np.array(samples).T
                    
            observations=np.stack(observations,axis=0)
            actions=np.array(actions,dtype=np.int32)
            next_observations=np.stack(next_observations,axis=0)
            rewards=np.array(rewards,dtype=np.float32)
            dones=np.array(dones,dtype=np.int32)

            curr_Qvals=self.policy_net.get_Qvals(observations)
            next_Qvals=self.target_net.get_target_Qvals(next_observations,current_step)
            returns=self.return_strat.get_return(rewards, (np.take_along_axis(next_Qvals,actions[:,None],axis=1)).ravel() ,dones,current_step)
            target_Qvals=np.copy(curr_Qvals)
            np.put_along_axis(target_Qvals , actions[:,None] , returns[:,None] , axis=1)
            
            self.policy_net.train_model(observations,target_Qvals)



class RL:

    def __init__(self,agent,env_manager,episodes_num=100,steps_per_episode=200):
        self.agent=agent
        self.env_manager=env_manager

        self.episodes_num=episodes_num
        self.steps_per_episode=steps_per_episode

        self.logs=None

        self.output=None
    
    def reset_logs(self):
        self.logs=dict({'episode':0,'step':0,'durations':[],'rewards':[],'exploration_rate':self.agent.explore_exploit_strat.get_exploration_rate(0),'last_policy':None,'last_action':None,'last_reward':None})

    def update_logs(self,experience,counter,ep,step):
        self.logs['episode']=ep
        self.logs['step']=step

        if(len(self.logs['durations'])<ep) : self.logs['durations'].append(step)
        else :  self.logs['durations'][ep-1]=step
        if(len(self.logs['rewards'])<ep) : self.logs['rewards'].append(experience[3])
        else :  self.logs['rewards'][ep-1]+=experience[3]

        self.logs['exploration_rate']=self.agent.explore_exploit_strat.get_exploration_rate(counter)
        self.logs['last_policy']=self.agent.policy_net.policy
        self.logs['last_action']=experience[1]
        self.logs['last_reward']=experience[3]

    def display_stats(self,mode):
          
        if(mode=="train"):

            if(self.logs['step']>1):
                sys.stdout.write("\b"*len(self.output))

            self.output="\n\n"
            self.output+="\nEpisode {}/{}".format(self.logs['episode'],self.episodes_num)
            self.output+="\nstep {}/{}".format(self.logs['step'],self.steps_per_episode)
            self.output+="\nexploration_rate:{}".format(self.logs['exploration_rate'])
            self.output+="\npolicy:{}".format(self.logs['last_policy'])
            self.output+="\naction:{}".format(self.logs['last_action'])
            self.output+="\nreward:{}".format(self.logs['last_reward'])

            self.output+="\ntotal episode reward:{}".format(self.logs['rewards'][-1])
            if(len(self.logs['durations'])>100) : self.output+="\nlast 100 episodes durations moving avg:{}".format(np.mean(np.array(self.logs['durations'][-100:])))
            if(len(self.logs['rewards'])>100) : self.output+="\nlast 100 episodes rewards moving avg:{}".format(np.mean(np.array(self.logs['rewards'][-100:])))

            sys.stdout.write(self.output)

        elif(mode=="test"):

            self.output="\n\n"
            self.output+="\nEpisode {}/{}".format(self.logs['episode'],self.episodes_num)
            self.output+="\nstep {}/{}".format(self.logs['step'],self.steps_per_episode)
            self.output+="\npolicy:{}".format(self.logs['last_policy'])
            self.output+="\naction:{}".format(self.logs['last_action'])
            self.output+="\nreward:{}".format(self.logs['last_reward'])

            self.output+="\ntotal episode reward:{}".format(self.logs['rewards'][-1])
            if(len(self.logs['durations'])>100) : self.output+="\nlast 100 episodes durations moving avg:{}".format(np.mean(np.array(self.logs['durations'][-100:])))
            if(len(self.logs['rewards'])>100) : self.output+="\nlast 100 episodes rewards moving avg:{}".format(np.mean(np.array(self.logs['rewards'][-100:])))

            sys.stdout.write(self.output)

    
    def start_train(self):
        self.reset_logs()

        self.env_manager.load()
        counter=0
        for ep in range(1,self.episodes_num+1):
            self.env_manager.reset()

            step=0
            while(1):
                step+=1;counter+=1

                experience=agent.take_action(counter) 

                self.update_logs(experience,counter,ep,step)
                self.display_stats(mode="train")

                agent.learn(experience,counter)

                if(step==self.steps_per_episode or experience[4]==1):
                    break

        env_manager.close()
        self.agent.policy_net.save_model()

    def start_test(self,episodes_num=10):
        self.episodes_num=episodes_num
        self.reset_logs()

        self.env_manager.load()
        counter=0
        for ep in range(1,episodes_num+1):
            self.env_manager.reset()

            step=0
            while(1):
                step+=1;counter+=1

                experience=agent.take_action(10**10)

                self.update_logs(experience,counter,ep,step)

                self.env_manager.render()
                self.display_stats(mode="test")
                time.sleep(0.1)

                if(step==self.steps_per_episode or experience[4]==1):
                    break
        env_manager.close()

# %%
env_manager=EnvManager(env_name='Breakout-v0')

policy_net=PolicyNet( load_name="",save_name="" )
policy_net.build_model(input_shape=(70,70,1),output_shape=3,loss="mse",learning_rate=0.001)
target_net=TargetNet(policy_net=policy_net,target_update=20)
target_net.build_model()

replay_mem=ReplayMemory(capacity=100000,batch_size=64)
explore_exploit_strat=ExploreExploitStrat( strategy=EpsilonGreedyStrategy(start=1.0,end=0.1,decay_rate=0.0001) )
return_strat=ReturnStrat( strategy=DiscountedReturn(Y=0.99) )

agent=Agent(env_manager,replay_mem,explore_exploit_strat,return_strat,policy_net,target_net)

rl=RL(agent,env_manager,episodes_num=200,steps_per_episode=500)

# %%
rl.start_train()
# Out:
# Streaming output truncated to the last 5000 lines.
# exploration_rate:0.5163785253831326
# policy:[0.41090426 0.4012685  0.18782721]
# action:0
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 70/500
# exploration_rate:0.5163368896124175
# policy:[0.41438603 0.40460163 0.18101235]
# action:0
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 71/500
# exploration_rate:0.5162952580050713
# policy:[0.4137168  0.40392965 0.18235359]
# action:0
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 72/500
# exploration_rate:0.5162536305606777
# policy:[0.4137168  0.40392965 0.18235359]
# action:0
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 73/500
# exploration_rate:0.5162120072788204
# policy:[0.41695705 0.40005392 0.18298902]
# action:0
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 74/500
# exploration_rate:0.5161703881590832
# policy:[0.41695705 0.40005392 0.18298902]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 75/500
# exploration_rate:0.5161287732010499
# policy:[0.41193783 0.4057826  0.1822795 ]
# action:0
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 76/500
# exploration_rate:0.5160871624043043
# policy:[0.41193783 0.4057826  0.1822795 ]
# action:0
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 77/500
# exploration_rate:0.5160455557684304
# policy:[0.41193783 0.4057826  0.1822795 ]
# action:2
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 78/500
# exploration_rate:0.5160039532930119
# policy:[0.41193783 0.4057826  0.1822795 ]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 79/500
# exploration_rate:0.515962354977633
# policy:[0.41193783 0.4057826  0.1822795 ]
# action:0
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 80/500
# exploration_rate:0.5159207608218778
# policy:[0.41193783 0.4057826  0.1822795 ]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 81/500
# exploration_rate:0.5158791708253301
# policy:[0.41193783 0.4057826  0.1822795 ]
# action:0
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 82/500
# exploration_rate:0.515837584987574
# policy:[0.41193783 0.4057826  0.1822795 ]
# action:0
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 83/500
# exploration_rate:0.515796003308194
# policy:[0.3941899  0.40883467 0.19697541]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 84/500
# exploration_rate:0.5157544257867738
# policy:[0.3941899  0.40883467 0.19697541]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 85/500
# exploration_rate:0.5157128524228979
# policy:[0.3941899  0.40883467 0.19697541]
# action:2
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 86/500
# exploration_rate:0.5156712832161506
# policy:[0.3941899  0.40883467 0.19697541]
# action:0
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 87/500
# exploration_rate:0.5156297181661161
# policy:[0.3941899  0.40883467 0.19697541]
# action:2
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 88/500
# exploration_rate:0.5155881572723788
# policy:[0.41149327 0.39927688 0.18922986]
# action:0
# reward:0.0
# total episode reward:0.0
#
#
# Episode 30/200
# step 89/500
# exploration_rate:0.5155466005345232
# policy:[0.41811836 0.3908819  0.19099972]
# action:0
# reward:1.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 90/500
# exploration_rate:0.5155050479521335
# policy:[0.41811836 0.3908819  0.19099972]
# action:1
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 91/500
# exploration_rate:0.5154634995247942
# policy:[0.41811836 0.3908819  0.19099972]
# action:2
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 92/500
# exploration_rate:0.51542195525209
# policy:[0.41811836 0.3908819  0.19099972]
# action:2
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 93/500
# exploration_rate:0.5153804151336053
# policy:[0.43148127 0.3950249  0.17349383]
# action:0
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 94/500
# exploration_rate:0.5153388791689248
# policy:[0.4278578  0.39476848 0.1773738 ]
# action:0
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 95/500
# exploration_rate:0.5152973473576331
# policy:[0.4278578  0.39476848 0.1773738 ]
# action:0
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 96/500
# exploration_rate:0.5152558196993149
# policy:[0.41148263 0.40267435 0.18584304]
# action:0
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 97/500
# exploration_rate:0.5152142961935549
# policy:[0.41148263 0.40267435 0.18584304]
# action:0
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 98/500
# exploration_rate:0.5151727768399378
# policy:[0.41519168 0.3972181  0.1875902 ]
# action:0
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 99/500
# exploration_rate:0.5151312616380485
# policy:[0.4143858 0.3984982 0.187116 ]
# action:0
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 100/500
# exploration_rate:0.5150897505874718
# policy:[0.4143858 0.3984982 0.187116 ]
# action:0
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 101/500
# exploration_rate:0.5150482436877926
# policy:[0.41565204 0.39580777 0.18854024]
# action:0
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 102/500
# exploration_rate:0.5150067409385959
# policy:[0.41565204 0.39580777 0.18854024]
# action:1
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 103/500
# exploration_rate:0.5149652423394665
# policy:[0.4031031  0.40299597 0.1939009 ]
# action:0
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 104/500
# exploration_rate:0.5149237478899896
# policy:[0.4031031  0.40299597 0.1939009 ]
# action:0
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 105/500
# exploration_rate:0.5148822575897501
# policy:[0.4031031  0.40299597 0.1939009 ]
# action:2
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 106/500
# exploration_rate:0.5148407714383334
# policy:[0.4031031  0.40299597 0.1939009 ]
# action:1
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 107/500
# exploration_rate:0.5147992894353243
# policy:[0.4031031  0.40299597 0.1939009 ]
# action:2
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 108/500
# exploration_rate:0.5147578115803081
# policy:[0.4031031  0.40299597 0.1939009 ]
# action:1
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 109/500
# exploration_rate:0.51471633787287
# policy:[0.4031031  0.40299597 0.1939009 ]
# action:0
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 110/500
# exploration_rate:0.5146748683125952
# policy:[0.4031031  0.40299597 0.1939009 ]
# action:0
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 111/500
# exploration_rate:0.5146334028990692
# policy:[0.4031031  0.40299597 0.1939009 ]
# action:0
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step 112/500
# exploration_rate:0.5145919416318773
# policy:[0.4031031  0.40299597 0.1939009 ]
# action:2
# reward:0.0
# total episode reward:1.0
#
#
# Episode 30/200
# step

# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 245/500
# exploration_rate:0.5091143753674848
# policy:[0.3850472  0.42811206 0.18684071]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 246/500
# exploration_rate:0.5090734659754518
# policy:[0.3850472  0.42811206 0.18684071]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 247/500
# exploration_rate:0.5090325606741534
# policy:[0.3850472  0.42811206 0.18684071]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 248/500
# exploration_rate:0.5089916594631806
# policy:[0.38522258 0.42478997 0.18998747]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 249/500
# exploration_rate:0.5089507623421244
# policy:[0.38522258 0.42478997 0.18998747]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 250/500
# exploration_rate:0.5089098693105758
# policy:[0.38407457 0.4254311  0.19049439]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 251/500
# exploration_rate:0.508868980368126
# policy:[0.38424575 0.4260322  0.1897221 ]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 252/500
# exploration_rate:0.5088280955143659
# policy:[0.38424575 0.4260322  0.1897221 ]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 253/500
# exploration_rate:0.5087872147488868
# policy:[0.38867307 0.42375243 0.18757449]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 254/500
# exploration_rate:0.5087463380712799
# policy:[0.38867307 0.42375243 0.18757449]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 255/500
# exploration_rate:0.5087054654811364
# policy:[0.386068   0.42597958 0.18795234]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 256/500
# exploration_rate:0.5086645969780474
# policy:[0.38553172 0.42647234 0.18799591]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 257/500
# exploration_rate:0.5086237325616044
# policy:[0.38553172 0.42647234 0.18799591]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 258/500
# exploration_rate:0.5085828722313989
# policy:[0.38553172 0.42647234 0.18799591]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 259/500
# exploration_rate:0.508542015987022
# policy:[0.3828535  0.4300922  0.18705425]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 260/500
# exploration_rate:0.5085011638280653
# policy:[0.3893018  0.44054842 0.17014976]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 261/500
# exploration_rate:0.5084603157541202
# policy:[0.3893018  0.44054842 0.17014976]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 262/500
# exploration_rate:0.5084194717647783
# policy:[0.3893018  0.44054842 0.17014976]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 263/500
# exploration_rate:0.5083786318596312
# policy:[0.3893018  0.44054842 0.17014976]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 264/500
# exploration_rate:0.5083377960382703
# policy:[0.38837543 0.43359545 0.17802909]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 265/500
# exploration_rate:0.5082969643002874
# policy:[0.38837543 0.43359545 0.17802909]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 266/500
# exploration_rate:0.5082561366452741
# policy:[0.38837543 0.43359545 0.17802909]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 267/500
# exploration_rate:0.5082153130728222
# policy:[0.38837543 0.43359545 0.17802909]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 268/500
# exploration_rate:0.5081744935825235
# policy:[0.3920331  0.4402322  0.16773474]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 269/500
# exploration_rate:0.5081336781739696
# policy:[0.39188802 0.4376853  0.17042668]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 270/500
# exploration_rate:0.5080928668467526
# policy:[0.39188802 0.4376853  0.17042668]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 271/500
# exploration_rate:0.5080520596004643
# policy:[0.38970894 0.43668717 0.17360392]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 272/500
# exploration_rate:0.5080112564346966
# policy:[0.38937777 0.43616015 0.17446207]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 273/500
# exploration_rate:0.5079704573490413
# policy:[0.38937777 0.43616015 0.17446207]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 274/500
# exploration_rate:0.5079296623430908
# policy:[0.38937777 0.43616015 0.17446207]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 275/500
# exploration_rate:0.5078888714164368
# policy:[0.38937777 0.43616015 0.17446207]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 276/500
# exploration_rate:0.5078480845686715
# policy:[0.38937777 0.43616015 0.17446207]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 277/500
# exploration_rate:0.507807301799387
# policy:[0.38937777 0.43616015 0.17446207]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 278/500
# exploration_rate:0.5077665231081757
# policy:[0.38663527 0.43071488 0.18264985]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 279/500
# exploration_rate:0.5077257484946295
# policy:[0.37320098 0.44026095 0.18653812]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 280/500
# exploration_rate:0.5076849779583408
# policy:[0.37320098 0.44026095 0.18653812]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 281/500
# exploration_rate:0.5076442114989019
# policy:[0.37320098 0.44026095 0.18653812]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 282/500
# exploration_rate:0.5076034491159052
# policy:[0.40416786 0.4328941  0.16293803]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 283/500
# exploration_rate:0.5075626908089429
# policy:[0.4058296  0.43438604 0.15978436]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 284/500
# exploration_rate:0.5075219365776076
# policy:[0.42298242 0.40855247 0.16846511]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 285/500
# exploration_rate:0.5074811864214915
# policy:[0.42298242 0.40855247 0.16846511]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 286/500
# exploration_rate:0.5074404403401874
# policy:[0.42298242 0.40855247 0.16846511]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 287/500
# exploration_rate:0.5073996983332877
# policy:[0.4015198  0.4244346  0.17404564]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 288/500
# exploration_rate:0.507358960400385
# policy:[0.40136382 0.4241837  0.17445251]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 289/500
# exploration_rate:0.5073182265410718
# policy:[0.40136382 0.4241837  0.17445251]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 290/500
# exploration_rate:0.5072774967549409
# policy:[0.4225762  0.39934996 0.1780738 ]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 291/500
# exploration_rate:0.507236771041585
# policy:[0.41543484 0.40669066 0.17787448]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 292/500
# exploration_rate:0.5071960494005969
# policy:[0.41543484 0.40669066 0.17787448]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 293/500
# exploration_rate:0.5071553318315692
# policy:[0.41543484 0.40669066 0.17787448]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 294/500
# exploration_rate:0.5071146183340949
# policy:[0.41543484 0.40669066 0.17787448]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 295/500
# exploration_rate:0.5070739089077667
# policy:[0.41543484 0.40669066 0.17787448]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 296/500
# exploration_rate:0.5070332035521776
# policy:[0.41543484 0.40669066 0.17787448]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 297/500
# exploration_rate:0.5069925022669206
# policy:[0.39799055 0.4344873  0.16752216]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 298/500
# exploration_rate:0.5069518050515885
# policy:[0.39799055 0.4344873  0.16752216]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 299/500
# exploration_rate:0.5069111119057746
# policy:[0.39741746 0.43361473 0.16896781]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 300/500
# exploration_rate:0.5068704228290718
# policy:[0.40034938 0.43072748 0.1689231 ]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 301/500
# exploration_rate:0.5068297378210732
# policy:[0.40034938 0.43072748 0.1689231 ]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 302/500
# exploration_rate:0.506789056881372
# policy:[0.40034366 0.42879274 0.17086364]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 303/500
# exploration_rate:0.5067483800095613
# policy:[0.4186026  0.40526542 0.17613198]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 304/500
# exploration_rate:0.5067077072052345
# policy:[0.4186026  0.40526542 0.17613198]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 305/500
# exploration_rate:0.5066670384679847
# policy:[0.4186026  0.40526542 0.17613198]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 306/500
# exploration_rate:0.5066263737974053
# policy:[0.4186026  0.40526542 0.17613198]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 307/500
# exploration_rate:0.5065857131930896
# policy:[0.4186026  0.40526542 0.17613198]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 308/500
# exploration_rate:0.5065450566546311
# policy:[0.4186026  0.40526542 0.17613198]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 309/500
# exploration_rate:0.5065044041816232
# policy:[0.4186026  0.40526542 0.17613198]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 310/500
# exploration_rate:0.5064637557736593
# policy:[0.406637   0.42296934 0.17039365]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 311/500
# exploration_rate:0.506423111430333
# policy:[0.406637   0.42296934 0.17039365]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 312/500
# exploration_rate:0.5063824711512378
# policy:[0.406637   0.42296934 0.17039365]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 313/500
# exploration_rate:0.5063418349359673
# policy:[0.406637   0.42296934 0.17039365]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 314/500
# exploration_rate:0.5063012027841152
# policy:[0.398463   0.43765965 0.16387734]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 315/500
# exploration_rate:0.5062605746952751
# policy:[0.398463   0.43765965 0.16387734]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 316/500
# exploration_rate:0.5062199506690407
# policy:[0.4065335  0.437853   0.15561351]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 317/500
# exploration_rate:0.5061793307050059
# policy:[0.41040292 0.44205555 0.14754154]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 318/500
# exploration_rate:0.5061387148027643
# policy:[0.41040292 0.44205555 0.14754154]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 319/500
# exploration_rate:0.5060981029619098
# policy:[0.41040292 0.44205555 0.14754154]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 320/500
# exploration_rate:0.5060574951820366
# policy:[0.41040292 0.44205555 0.14754154]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 321/500
# exploration_rate:0.5060168914627381
# policy:[0.40348345 0.43790916 0.15860742]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 322/500
# exploration_rate:0.5059762918036087
# policy:[0.40049574 0.44177315 0.15773115]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 323/500
# exploration_rate:0.5059356962042421
# policy:[0.40049574 0.44177315 0.15773115]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 324/500
# exploration_rate:0.5058951046642325
# policy:[0.40049574 0.44177315 0.15773115]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 325/500
# exploration_rate:0.505854517183174
# policy:[0.40049574 0.44177315 0.15773115]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 326/500
# exploration_rate:0.5058139337606606
# policy:[0.40049574 0.44177315 0.15773115]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 327/500
# exploration_rate:0.5057733543962865
# policy:[0.40049574 0.44177315 0.15773115]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 328/500
# exploration_rate:0.505732779089646
# policy:[0.4096313  0.4273309  0.16303775]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 329/500
# exploration_rate:0.5056922078403333
# policy:[0.40767562 0.42968735 0.16263701]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 330/500
# exploration_rate:0.5056516406479428
# policy:[0.3807846  0.45054245 0.16867302]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 331/500
# exploration_rate:0.5056110775120686
# policy:[0.36064395 0.46868432 0.17067178]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 332/500
# exploration_rate:0.5055705184323052
# policy:[0.36064395 0.46868432 0.17067178]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 333/500
# exploration_rate:0.505529963408247
# policy:[0.36064395 0.46868432 0.17067178]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 334/500
# exploration_rate:0.5054894124394883
# policy:[0.4079463  0.43795863 0.15409505]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 335/500
# exploration_rate:0.5054488655256238
# policy:[0.40702358 0.4367083  0.15626813]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 336/500
# exploration_rate:0.505408322666248
# policy:[0.40702358 0.4367083  0.15626813]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 337/500
# exploration_rate:0.5053677838609554
# policy:[0.40702358 0.4367083  0.15626813]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 338/500
# exploration_rate:0.5053272491093407
# policy:[0.40702358 0.4367083  0.15626813]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 339/500
# exploration_rate:0.5052867184109985
# policy:[0.4121351  0.43240485 0.15546012]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 340/500
# exploration_rate:0.5052461917655234
# policy:[0.41020823 0.4333772  0.1564146 ]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 341/500
# exploration_rate:0.5052056691725103
# policy:[0.40838414 0.43340814 0.15820774]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 342/500
# exploration_rate:0.5051651506315539
# policy:[0.40838414 0.43340814 0.15820774]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 343/500
# exploration_rate:0.505124636142249
# policy:[0.40838414 0.43340814 0.15820774]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 344/500
# exploration_rate:0.5050841257041904
# policy:[0.40838414 0.43340814 0.15820774]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 345/500
# exploration_rate:0.5050436193169731
# policy:[0.40838414 0.43340814 0.15820774]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 346/500
# exploration_rate:0.505003116980192
# policy:[0.43346858 0.41785958 0.1486718 ]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 347/500
# exploration_rate:0.5049626186934421
# policy:[0.43346858 0.41785958 0.1486718 ]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 348/500
# exploration_rate:0.5049221244563182
# policy:[0.42360538 0.4246955  0.15169913]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 349/500
# exploration_rate:0.5048816342684158
# policy:[0.42360538 0.4246955  0.15169913]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 350/500
# exploration_rate:0.5048411481293297
# policy:[0.42360538 0.4246955  0.15169913]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 30/200
# step 351/500
# exploration_rate:0.504800666038655
# policy:[0.42360538 0.4246955  0.15169913]
# action:1
# reward:-10
# total episode reward:-7.0
#
#
# Episode 31/200
# step 1/500
# exploration_rate:0.504760187995987
# policy:[0.42360538 0.4246955  0.15169913]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 2/500
# exploration_rate:0.5047197140009209
# policy:[0.41159496 0.43149734 0.1569077 ]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 3/500
# exploration_rate:0.5046792440530519
# policy:[0.41159496 0.43149734 0.1569077 ]
# action:0
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 4/500
# exploration_rate:0.5046387781519753
# policy:[0.40970996 0.43198413 0.15830593]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 5/500
# exploration_rate:0.5045983162972867
# policy:[0.40970996 0.43198413 0.15830593]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 6/500
# exploration_rate:0.504557858488581
# policy:[0.41333488 0.43578    0.1508851 ]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 7/500
# exploration_rate:0.504517404725454
# policy:[0.41145712 0.43546653 0.15307635]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 8/500
# exploration_rate:0.5044769550075011
# policy:[0.41145712 0.43546653 0.15307635]
# action:2
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 9/500
# exploration_rate:0.5044365093343177
# policy:[0.40975612 0.4345733  0.15567058]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 10/500
# exploration_rate:0.5043960677054994
# policy:[0.40975612 0.4345733  0.15567058]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 11/500
# exploration_rate:0.5043556301206418
# policy:[0.40975612 0.4345733  0.15567058]
# action:0
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 12/500
# exploration_rate:0.5043151965793405
# policy:[0.40975612 0.4345733  0.15567058]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 13/500
# exploration_rate:0.5042747670811912
# policy:[0.39278114 0.44422314 0.16299577]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 14/500
# exploration_rate:0.5042343416257895
# policy:[0.40067586 0.43639845 0.1629256 ]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 15/500
# exploration_rate:0.5041939202127314
# policy:[0.40067586 0.43639845 0.1629256 ]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 16/500
# exploration_rate:0.5041535028416122
# policy:[0.40879864 0.440611   0.15059039]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 17/500
# exploration_rate:0.5041130895120282
# policy:[0.40879864 0.440611   0.15059039]
# action:0
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 18/500
# exploration_rate:0.5040726802235751
# policy:[0.41924897 0.4164069  0.16434416]
# action:0
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 19/500
# exploration_rate:0.5040322749758488
# policy:[0.41924897 0.4164069  0.16434416]
# action:0
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 20/500
# exploration_rate:0.5039918737684453
# policy:[0.41914618 0.41841668 0.16243716]
# action:0
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 21/500
# exploration_rate:0.5039514766009605
# policy:[0.41914618 0.41841668 0.16243716]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 22/500
# exploration_rate:0.5039110834729904
# policy:[0.41914618 0.41841668 0.16243716]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 23/500
# exploration_rate:0.5038706943841312
# policy:[0.41914618 0.41841668 0.16243716]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 24/500
# exploration_rate:0.503830309333979
# policy:[0.41914618 0.41841668 0.16243716]
# action:0
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 25/500
# exploration_rate:0.5037899283221299
# policy:[0.4170011  0.4193079  0.16369106]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 26/500
# exploration_rate:0.5037495513481799
# policy:[0.4170011  0.4193079  0.16369106]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 27/500
# exploration_rate:0.5037091784117256
# policy:[0.4170011  0.4193079  0.16369106]
# action:2
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 28/500
# exploration_rate:0.503668809512363
# policy:[0.41619447 0.42527324 0.15853232]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 29/500
# exploration_rate:0.5036284446496886
# policy:[0.41619447 0.42527324 0.15853232]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 30/500
# exploration_rate:0.5035880838232986
# policy:[0.4139995  0.42790207 0.15809835]
# action:1
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 31/500
# exploration_rate:0.5035477270327894
# policy:[0.4139995  0.42790207 0.15809835]
# action:2
# reward:0.0
# total episode reward:0.0
#
#
# Episode 31/200
# step 32/500
# ...
# action:2
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 202/500
# exploration_rate:0.4967057267247921
# policy:[0.38091266 0.46061146 0.15847592]
# action:2
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 203/500
# exploration_rate:0.4966660581355822
# policy:[0.3734278  0.46265274 0.16391939]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 204/500
# exploration_rate:0.4966263935130327
# policy:[0.34982482 0.4842091  0.16596608]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 205/500
# exploration_rate:0.49658673285674726
# policy:[0.34982482 0.4842091  0.16596608]
# action:2
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 206/500
# exploration_rate:0.4965470761663292
# policy:[0.34982482 0.4842091  0.16596608]
# action:2
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 207/500
# exploration_rate:0.4965074234413819
# policy:[0.34982482 0.4842091  0.16596608]
# action:2
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 208/500
# exploration_rate:0.4964677746815087
# policy:[0.37899616 0.4641445  0.15685932]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 209/500
# exploration_rate:0.49642812988631335
# policy:[0.38512486 0.45391488 0.1609602 ]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 210/500
# exploration_rate:0.49638848905539934
# policy:[0.38512486 0.45391488 0.1609602 ]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 211/500
# exploration_rate:0.4963488521883702
# policy:[0.36425537 0.46989343 0.16585122]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 212/500
# exploration_rate:0.4963092192848295
# policy:[0.36425537 0.46989343 0.16585122]
# action:0
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 213/500
# exploration_rate:0.4962695903443811
# policy:[0.3703384  0.46367615 0.16598545]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 214/500
# exploration_rate:0.49622996536662856
# policy:[0.3703384  0.46367615 0.16598545]
# action:0
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 215/500
# exploration_rate:0.4961903443511757
# policy:[0.37574738 0.46090946 0.16334318]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 216/500
# exploration_rate:0.4961507272976263
# policy:[0.37574738 0.46090946 0.16334318]
# action:2
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 217/500
# exploration_rate:0.4961111142055842
# policy:[0.37574738 0.46090946 0.16334318]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 218/500
# exploration_rate:0.49607150507465314
# policy:[0.3823909  0.45561227 0.16199683]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 219/500
# exploration_rate:0.4960318999044372
# policy:[0.3823909  0.45561227 0.16199683]
# action:2
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 220/500
# exploration_rate:0.4959922986945402
# policy:[0.38241944 0.4553503  0.1622302 ]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 221/500
# exploration_rate:0.49595270144456627
# policy:[0.38241944 0.4553503  0.1622302 ]
# action:2
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 222/500
# exploration_rate:0.49591310815411926
# policy:[0.3859144  0.4590115  0.15507407]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 223/500
# exploration_rate:0.4958735188228035
# policy:[0.39363796 0.4463222  0.16003984]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 224/500
# exploration_rate:0.49583393345022286
# policy:[0.39363796 0.4463222  0.16003984]
# action:0
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 225/500
# exploration_rate:0.49579435203598143
# policy:[0.39363796 0.4463222  0.16003984]
# action:2
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 226/500
# exploration_rate:0.49575477457968364
# policy:[0.37754476 0.4568142  0.16564105]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 227/500
# exploration_rate:0.4957152010809337
# policy:[0.3778171  0.45487568 0.16730729]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 228/500
# exploration_rate:0.4956756315393356
# policy:[0.3778171  0.45487568 0.16730729]
# action:0
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 229/500
# exploration_rate:0.49563606595449383
# policy:[0.37051615 0.46122524 0.1682586 ]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 230/500
# exploration_rate:0.49559650432601277
# policy:[0.37514117 0.45838442 0.16647439]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 231/500
# exploration_rate:0.4955569466534968
# policy:[0.3753738  0.45753357 0.1670926 ]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 232/500
# exploration_rate:0.4955173929365503
# policy:[0.3753738  0.45753357 0.1670926 ]
# action:0
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 233/500
# exploration_rate:0.4954778431747776
# policy:[0.35935736 0.46848628 0.17215636]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 234/500
# exploration_rate:0.49543829736778344
# policy:[0.36386663 0.465186   0.17094734]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 235/500
# exploration_rate:0.4953987555151723
# policy:[0.36386663 0.465186   0.17094734]
# action:0
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 236/500
# exploration_rate:0.49535921761654866
# policy:[0.3691612  0.4613207  0.16951807]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 237/500
# exploration_rate:0.49531968367151724
# policy:[0.3691612  0.4613207  0.16951807]
# action:0
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 238/500
# exploration_rate:0.4952801536796826
# policy:[0.3691612  0.4613207  0.16951807]
# action:0
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 239/500
# exploration_rate:0.49524062764064947
# policy:[0.3691612  0.4613207  0.16951807]
# action:0
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 240/500
# exploration_rate:0.49520110555402275
# policy:[0.378777   0.46144876 0.1597743 ]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 241/500
# exploration_rate:0.49516158741940697
# policy:[0.378777   0.46144876 0.1597743 ]
# action:0
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 242/500
# exploration_rate:0.4951220732364071
# policy:[0.378777   0.46144876 0.1597743 ]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 243/500
# exploration_rate:0.49508256300462794
# policy:[0.378777   0.46144876 0.1597743 ]
# action:0
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 244/500
# exploration_rate:0.49504305672367455
# policy:[0.378777   0.46144876 0.1597743 ]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 245/500
# exploration_rate:0.4950035543931516
# policy:[0.3752495  0.45762876 0.16712177]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 246/500
# exploration_rate:0.49496405601266413
# policy:[0.3752495  0.45762876 0.16712177]
# action:2
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 247/500
# exploration_rate:0.4949245615818174
# policy:[0.3752495  0.45762876 0.16712177]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 248/500
# exploration_rate:0.4948850711002162
# policy:[0.3752495  0.45762876 0.16712177]
# action:0
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 249/500
# exploration_rate:0.49484558456746564
# policy:[0.3687333  0.46189374 0.16937296]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 250/500
# exploration_rate:0.4948061019831711
# policy:[0.3687333  0.46189374 0.16937296]
# action:2
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 251/500
# exploration_rate:0.49476662334693744
# policy:[0.3687333  0.46189374 0.16937296]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 252/500
# exploration_rate:0.4947271486583701
# policy:[0.37061197 0.45980543 0.16958259]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 253/500
# exploration_rate:0.49468767791707413
# policy:[0.37064922 0.45973957 0.16961123]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 254/500
# exploration_rate:0.4946482111226551
# policy:[0.37064922 0.45973957 0.16961123]
# action:0
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 255/500
# exploration_rate:0.4946087482747181
# policy:[0.37064922 0.45973957 0.16961123]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 256/500
# exploration_rate:0.4945692893728687
# policy:[0.37064922 0.45973957 0.16961123]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 257/500
# exploration_rate:0.49452983441671206
# policy:[0.37064922 0.45973957 0.16961123]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 258/500
# exploration_rate:0.4944903834058537
# policy:[0.3706244  0.46021748 0.1691582 ]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 259/500
# exploration_rate:0.49445093633989934
# policy:[0.3706244  0.46021748 0.1691582 ]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 260/500
# exploration_rate:0.49441149321845423
# policy:[0.3500599  0.47599602 0.17394404]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 261/500
# exploration_rate:0.49437205404112416
# policy:[0.34960425 0.47545516 0.17494056]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 262/500
# exploration_rate:0.49433261880751456
# policy:[0.34960425 0.47545516 0.17494056]
# action:0
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 263/500
# exploration_rate:0.4942931875172313
# policy:[0.3614944  0.4660371  0.17246844]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 264/500
# exploration_rate:0.49425376016987976
# policy:[0.36364067 0.46436733 0.17199196]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 265/500
# exploration_rate:0.4942143367650659
# policy:[0.36560363 0.46287164 0.1715248 ]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 266/500
# exploration_rate:0.4941749173023954
# policy:[0.3434637  0.4803107  0.17622563]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 267/500
# exploration_rate:0.49413550178147403
# policy:[0.3434637  0.4803107  0.17622563]
# action:2
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 268/500
# exploration_rate:0.4940960902019076
# policy:[0.35665187 0.4692421  0.17410603]
# action:1
# reward:0.0
# total episode reward:2.0
#
#
# Episode 31/200
# step 269/500
# exploration_rate:0.49405668256330226
# policy:[0.33946854 0.4828742  0.17765723]
# action:1
# reward:1.0
# total episode reward:3.0
#
#
# Episode 31/200
# step 270/500
# exploration_rate:0.4940172788652637
# policy:[0.33946854 0.4828742  0.17765723]
# action:2
# reward:0.0
# total episode reward:3.0
#
#
# Episode 31/200
# step 271/500
# exploration_rate:0.4939778791073979
# policy:[0.33946854 0.4828742  0.17765723]
# action:0
# reward:0.0
# total episode reward:3.0
#
#
# Episode 31/200
# step 272/500
# exploration_rate:0.4939384832893108
# policy:[0.37461627 0.4333519  0.19203182]
# action:1
# reward:0.0
# total episode reward:3.0
#
#
# Episode 31/200
# step 273/500
# exploration_rate:0.4938990914106087
# policy:[0.37087598 0.43965045 0.18947352]
# action:1
# reward:0.0
# total episode reward:3.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-49845acda539> in <module>()
# ----> 1 rl.start_train()
#
# <ipython-input-2-2b25f9fe82ba> in start_train(self)
#     349                 self.display_stats(mode="train")
#     350
# --> 351                 agent.learn(experience,counter)
#     352
#     353                 if(step==self.steps_per_episode or experience[4]==1):
#
# <ipython-input-2-2b25f9fe82ba> in learn(self, experience, current_step)
#     261             np.put_along_axis(target_Qvals , actions[:,None] , returns[:,None] , axis=1)
#     262
# --> 263             self.policy_net.train_model(observations,target_Qvals)
#     264
#     265
#
# <ipython-input-2-2b25f9fe82ba> in train_model(self, inputs, outputs)
#      55     def train_model(self,inputs,outputs):
#      56         inputs=self.preprocess_inputs(inputs)
# ---> 57         self.model.fit(inputs.astype(np.float32),outputs.astype(np.float32),epochs=1,batch_size=1,verbose=0,shuffle=False)
#      58
#      59     def get_Qvals(self,inputs):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
rl.start_test(episodes_num=10)
# Out:
# <PIL.Image.Image image mode=RGB size=160x210 at 0x7F49F7FAEFD0>
# Episode 1/10
# step 95/500
# policy:[0.3537738  0.4532705  0.19295573]
# action:1
# reward:0.0
# total episode reward:0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-0486f829713b> in <module>()
# ----> 1 rl.start_test(episodes_num=10)
#
# <ipython-input-2-2b25f9fe82ba> in start_test(self, episodes_num)
#     376                 self.env_manager.render()
#     377                 self.display_stats(mode="test")
# --> 378                 time.sleep(0.1)
#     379
#     380                 if(step==self.steps_per_episode or experience[4]==1):
#
# KeyboardInterrupt:
